# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-4 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> Keras Regression Code Along Project </h2> </html>
#
# Let's now apply our knowledge to a more realistic data set. Here we will also focus on feature engineering and cleaning our data!

# %% [markdown]
# ## The Data
#
# We will be using data from a Kaggle data set:
#
# https://www.kaggle.com/harlfoxem/housesalesprediction
#
# #### Feature Columns
#
# * id - Unique ID for each home sold
# * date - Date of the home sale
# * price - Price of each home sold
# * bedrooms - Number of bedrooms
# * bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * sqft_living - Square footage of the apartments interior living space
# * sqft_lot - Square footage of the land space
# * floors - Number of floors
# * waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
# * view - An index from 0 to 4 of how good the view of the property was
# * condition - An index from 1 to 5 on the condition of the apartment,
# * grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * sqft_above - The square footage of the interior housing space that is above ground level
# * sqft_basement - The square footage of the interior housing space that is below ground level
# * yr_built - The year the house was initially built
# * yr_renovated - The year of the house’s last renovation
# * zipcode - What zipcode area the house is in
# * lat - Lattitude
# * long - Longitude
# * sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors
#
# #### The problem
# * Develop a neural network model to predict the house price based on the above features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ______________![image.png](attachment:c286e15c-c531-4f87-b9c8-7b53019f2f49.png)

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# _____________![image.png](attachment:48d72b58-1a11-4faf-b0e8-463a0bd4dfbf.png)

# %%
df = pd.read_csv('kc_house_data-1.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Your code to print the info of the dataset
# Hint - use dataset.info()

# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Perform some data analysis using the libraries above.
# Visualise the features to understand the problem and use the appropriate features for the model.

# %%
# Your code to check if any null value is present in the dataset.
# Hint - use isnull() in pandas

# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Your code to describe the dataset to get imortant properties of it.
# Hint - describe().transpose()

# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# ### Let's see how price columns look like i.e. how prices are distributed.

# %% [markdown]
# ____________![image.png](attachment:63865e40-9f88-41c2-bf89-31e4f3cc8b54.png)

# %%
plt.figure(figsize=(12,8))
sns.set_theme()
sns.histplot(df['price'], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# #### Let's look at the columns - number of bedroom in more detail

# %% [markdown]
# ________________![image.png](attachment:6e6a8cb3-c069-4ca3-bf91-21ef90cdd5e2.png)

# %%
sns.countplot(x='bedrooms', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %% [markdown]
# ___________________![image.png](attachment:aae27f1e-fcaf-413d-881d-4da27d6a414c.png)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price', y='sqft_living', data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %% [markdown]
# ________________![image.png](attachment:e01c31ea-be78-471f-b0e0-dbc7b17b12a8.png)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ## Geographical Properties
#
# Visualise scatter plots between price and longitude (long) and latitude (lat) columns.

# %% [markdown]
# _____________![image.png](attachment:f43991f7-65a1-42e2-9a07-397557410c2c.png)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='price', data=df)
# Out:
# <Axes: xlabel='long', ylabel='price'>

# %%
# Your code to visualise a scatter plot between price and latitude(lat) columns

# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price', y='lat', data=df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %% [markdown]
# _________________![image.png](attachment:b97235c1-5652-4b23-8cbc-7fc7619f6a35.png)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat', data=df, hue='price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# #### Compare the graph above with the following maps

# %% [markdown]
# ![image.png](attachment:1da2d004-5f37-4b2f-a941-16492060df4b.png)

# %% [markdown]
# ![image.png](attachment:1748fc24-880a-48d5-87ee-eff3d0a6f06a.png)

# %% [markdown]
# ### Sort the values in the dataframe according to price and print first few rows.

# %%
# Your code to sort data frame according to the price (ascending order) and see the first few rows.
# Hint - Use df.sort_values and combine it with head()

# ...

# %%
df.sort_values(by='price').head()
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0           0     0  ...      3         670
# 15293     16344     1.0           0     0  ...      5         780
# 465        5050     1.0           0     0  ...      4         430
# 16198      9975     1.0           0     0  ...      5         730
# 8274      10426     1.0           0     0  ...      6         860
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149               0      1966             0    98022  47.2638 -121.906
# 15293              0      1942             0    98168  47.4739 -122.280
# 465                0      1912             0    98014  47.6499 -121.909
# 16198              0      1943             0    98168  47.4808 -122.315
# 8274               0      1954             0    98146  47.4987 -122.341
#
#        sqft_living15  sqft_lot15
# 1149            1160       42882
# 15293           1700       10387
# 465             1200        7500
# 16198            860        9000
# 8274            1140       11250
#
# [5 rows x 21 columns]

# %% [markdown]
# #### The following code visualises the price intensity with the latitude and longitude for 1% and 99% of the data separately.
#
# #### You need to add a comment on each line of the code.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next 3 cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
len(df)*(0.01)
# Out:
# 216.13

# %%
non_top_1_perc = df.sort_values('price',ascending=False).iloc[216:]
non_top_1_perc
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3281   8964800025  20150226T000000  1965000.0         5       3.75
# 12577  2806300065  20150422T000000  1960000.0         4       4.00
# 12283  1923000260  20141015T000000  1959000.0         5       4.50
# 1152   4055701200  20150421T000000  1955000.0         4       2.75
# 9175   3124059023  20150213T000000  1955000.0         3       1.75
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3281          3940     13738     1.5           0     3  ...      9
# 12577         4430     31353     2.0           0     0  ...     12
# 12283         6200     23373     3.0           0     1  ...     11
# 1152          3120      7898     1.0           1     4  ...      8
# 9175          3330     12566     1.0           1     4  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 8274           860     10426     1.0           0     0  ...      6
# 16198          730      9975     1.0           0     0  ...      5
# 465            430      5050     1.0           0     0  ...      4
# 15293          780     16344     1.0           0     0  ...      5
# 1149           670     43377     1.0           0     0  ...      3
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3281         3940              0      1951             0    98004  47.6203
# 12577        4430              0      1998             0    98005  47.6422
# 12283        5050           1150      1988             0    98040  47.5632
# 1152         1560           1560      1963             0    98034  47.7165
# 9175         1940           1390      1960             0    98040  47.5287
# ...           ...            ...       ...           ...      ...      ...
# 8274          860              0      1954             0    98146  47.4987
# 16198         730              0      1943             0    98168  47.4808
# 465           430              0      1912             0    98014  47.6499
# 15293         780              0      1942             0    98168  47.4739
# 1149          670              0      1966             0    98022  47.2638
#
#           long  sqft_living15  sqft_lot15
# 3281  -122.212           2370       13320
# 12577 -122.157           3900       35237
# 12283 -122.215           3700       14486
# 1152  -122.259           2630       13868
# 9175  -122.220           3730       16560
# ...        ...            ...         ...
# 8274  -122.341           1140       11250
# 16198 -122.315            860        9000
# 465   -121.909           1200        7500
# 15293 -122.280           1700       10387
# 1149  -121.906           1160       42882
#
# [21397 rows x 21 columns]

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='long',y='lat',
                data=non_top_1_perc,hue='price',
                palette='RdYlGn',edgecolor=None,alpha=0.2)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# ## Other Features
#
# ### Let's have a box plot between waterfront and price.
#
# ### Explain what box plot is doing?

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ## Working with Feature Data

# %%
# Your code to print the first few rows of the data

# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
# Your code to print info about the data

# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
# Following code is dropping the column ID.
# Question - why are dropping this column?

# Run the code only once!

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# Run the code only once!

df = df.drop('id',axis=1)

# %% [markdown]
# ### Feature Engineering from Date
#
# Transform the features into useful formats to apply appropriate Deep NN technique!

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next 3 cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)

# %%
# Check what the above code is doing

df.head(3)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014
# 2    98028  47.7379 -122.233           2720        8062      2  2015
#
# [3 rows x 22 columns]

# %% [markdown]
# _____________________________![image.png](attachment:5d187e37-971e-4b02-9f0f-da16e49a44b8.png)

# %%
sns.boxplot(x='year', y='price', data=df)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
# Your code to visualise e boxplot between month and price

# ...

# %%
sns.boxplot(x='month', y='price', data=df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next 2 cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %%
# Should we remove zipcode?

df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# ________________![image.png](attachment:a9bb6310-11e9-4911-b27d-6b5901f69584.png)

# %%
df = df.drop('date', axis=1)

# %%
# Your code to remove zip code
# Hint - Use df.drop

# ...
df = df.drop('zipcode', axis=1)

# %% [markdown]
# ______________![image.png](attachment:1269ffb0-9604-4708-8c2a-5f601b282767.png)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# 0  47.5112 -122.257           1340        5650     10  2014
# 1  47.7210 -122.319           1690        7639     12  2014
# 2  47.7379 -122.233           2720        8062      2  2015
# 3  47.5208 -122.393           1360        5000     12  2014
# 4  47.6168 -122.045           1800        7503      2  2015

# %% [markdown]
# _________________![image.png](attachment:02915586-e6aa-422f-9899-5d799934e17e.png)

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1948        1
# 1951        1
# 1959        1
# 1934        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# ____________________![image.png](attachment:9914f12c-d524-4bc1-8f7e-696ca24e7b66.png)

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 176         1
# 225         1
# 1275        1
# 274         1
# 248         1
# Name: count, Length: 306, dtype: int64

# %% [markdown]
# ## Scaling and Train Test Split
#
# Scikit-Learn is used to split out the train-test library.

# %% [markdown]
# First separate input and output. Input will be stored in the variable X and output in variable y.

# %% [markdown]
# __________________![image.png](attachment:9cc989f0-09a7-4fec-81ad-cf14890c185e.png)

# %%
df.shape
# Out:
# (21613, 20)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# Store all columns except the price column in variable X

X = df.drop('price',axis=1)
X.shape
# Out:
# (21613, 19)

# %% [markdown]
# ____________![image.png](attachment:eef03023-dc81-4823-85e4-9d40c8e070a3.png)

# %%
y = df['price']
y.shape
# Out:
# (21613,)

# %% [markdown]
# ______________![image.png](attachment:2abe3a43-c0a1-4ef5-b4fd-bbbf75bf9176.png)

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ________![image.png](attachment:51d1d13e-efb0-46df-a74c-0379c904d355.png)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ___________________![image.png](attachment:3ee588a6-29b4-4e29-b418-773e6b95f889.png)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (15129, 19) (6484, 19) (15129,) (6484,)

# %% [markdown]
# ### Scaling
#
# Features are scaled to be in a proper range to be useful for modeling.
# Scaling converts all values between 0-1.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# fit_transform() is used on the training data so that we can scale the training data and also learn the scaling parameters of that data, such as the mean and variance of the features of the training set. These learned and fixed parameters are then used to scale our test data with the transform() function.

# %%
# Your code to print shapes of X_train, X_test, y_train, y_test and see if shapes are okay.

# .....

# The shape shouldn't be changed

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (15129, 19) (6484, 19) (15129,) (6484,)

# %% [markdown]
# ## Creating a Model
#
# Build a Deep NN model with appropriate layers using Keras.

# %% [markdown]
# Develop your own Neural Network model with suitable numbers of input, output, and any number of hidden layers.
#
# Use the code  for input layer: input_shape=(X_train.shape[1],)
#
# Since we are predicting a value, the number of neurons in the output layer should be one.

# %%
# Your code to build MLP neural network model.

model = keras.Sequential()
model.add(keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Training the Model
#
# Write the code to train the neural network model. Use the following of your choice:
#
#
#
# 1.   Optimization method
# 2.   Batch size
# 3.   Number of epochs.
#
# Test for various optimizers and check which one performs better in terms of loss function = 'mse'.
#
# Use following APIs
# * https://keras.io/api/optimizers/
# * https://keras.io/api/losses/regression_losses/
# * https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics
# * https://keras.io/api/models/model_training_apis/

# %%
# ! add your chosen optimiser !

model.compile(optimizer='adam', loss='mse')

# %%
# Your code to train the model.
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 402629361664.0000 - val_loss: 250870235136.0000
# Epoch 2/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 141852819456.0000 - val_loss: 81026465792.0000
# Epoch 3/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 100497719296.0000 - val_loss: 77270646784.0000
# Epoch 4/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95758000128.0000 - val_loss: 73535266816.0000
# Epoch 5/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90660986880.0000 - val_loss: 69277687808.0000
# Epoch 6/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 85280489472.0000 - val_loss: 64877576192.0000
# Epoch 7/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 79249735680.0000 - val_loss: 59966898176.0000
# Epoch 8/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 73061244928.0000 - val_loss: 55373422592.0000
# Epoch 9/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 67157819392.0000 - val_loss: 51015860224.0000
# Epoch 10/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62101078016.0000 - val_loss: 48075767808.0000
# Epoch 11/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 58355605504.0000 - val_loss: 45504053248.0000
# Epoch 12/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 55764422656.0000 - val_loss: 43998384128.0000
# Epoch 13/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 54029348864.0000 - val_loss: 42900316160.0000
# Epoch 14/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 52690731008.0000 - val_loss: 41965297664.0000
# Epoch 15/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 51591090176.0000 - val_loss: 41456398336.0000
# Epoch 16/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 50653839360.0000 - val_loss: 40749019136.0000
# Epoch 17/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 49841512448.0000 - val_loss: 39967637504.0000
# Epoch 18/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 49027108864.0000 - val_loss: 39234723840.0000
# Epoch 19/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 48242270208.0000 - val_loss: 38724186112.0000
# Epoch 20/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 47575822336.0000 - val_loss: 38125998080.0000
# Epoch 21/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 46874202112.0000 - val_loss: 37668261888.0000
# Epoch 22/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 46172184576.0000 - val_loss: 37448261632.0000
# Epoch 23/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 45584580608.0000 - val_loss: 36904398848.0000
# Epoch 24/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44954689536.0000 - val_loss: 36889710592.0000
# Epoch 25/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 44385177600.0000 - val_loss: 36657614848.0000
# Epoch 26/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 43883085824.0000 - val_loss: 35773497344.0000
# Epoch 27/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 43366596608.0000 - val_loss: 35484487680.0000
# Epoch 28/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 42932633600.0000 - val_loss: 35873439744.0000
# Epoch 29/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42438168576.0000 - val_loss: 34992775168.0000
# Epoch 30/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41887809536.0000 - val_loss: 34757226496.0000
# Epoch 31/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41449406464.0000 - val_loss: 34551308288.0000
# Epoch 32/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40905175040.0000 - val_loss: 34803277824.0000
# Epoch 33/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40530665472.0000 - val_loss: 33972969472.0000
# Epoch 34/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 40153903104.0000 - val_loss: 33760272384.0000
# Epoch 35/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 39805591552.0000 - val_loss: 33817559040.0000
# Epoch 36/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39507484672.0000 - val_loss: 33454960640.0000
# Epoch 37/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39133892608.0000 - val_loss: 33300342784.0000
# Epoch 38/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38901350400.0000 - val_loss: 33462777856.0000
# Epoch 39/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 38570663936.0000 - val_loss: 32990693376.0000
# Epoch 40/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38347173888.0000 - val_loss: 32955867136.0000
# Epoch 41/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38103425024.0000 - val_loss: 32797241344.0000
# Epoch 42/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 37858226176.0000 - val_loss: 32785055744.0000
# Epoch 43/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 37628125184.0000 - val_loss: 32890984448.0000
# Epoch 44/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 37441114112.0000 - val_loss: 32569915392.0000
# Epoch 45/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 37254877184.0000 - val_loss: 32476362752.0000
# Epoch 46/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37063323648.0000 - val_loss: 32427993088.0000
# Epoch 47/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36855373824.0000 - val_loss: 32385101824.0000
# Epoch 48/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36735234048.0000 - val_loss: 32227831808.0000
# Epoch 49/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36567359488.0000 - val_loss: 32142211072.0000
# Epoch 50/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 36408004608.0000 - val_loss: 32082112512.0000

# %% [markdown]
# ### Following code gets the history of losses at every epoch.

# %% [markdown]
# ____________![image.png](attachment:a475db66-9e7c-4c9e-8fe1-f97b4f243e6a.png)

# %%
losses = pd.DataFrame(history.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# ________________![image.png](attachment:61f49706-d884-4c8f-aaca-0879a1d2db41.png)

# %%
history_dict = history.history
Loss = losses['loss']
plt.figure(num=1, figsize=(15,7))
plt.plot(Loss, 'bo', label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation on Test Data
#
# https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics
#
# Scikit-Learn has metrics to evaluate the performance.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %% [markdown]
# #### Next, we will test the performance of our model by predicting on test dataset X_test.

# %% [markdown]
# ______________________![image.png](attachment:2a8cf966-bc06-4b02-980e-6e7254d65dd2.png)

# %%
print(X_test)
# Out:
# [[0.18181818 0.125      0.05735849 ... 0.010289   0.         1.        ]
#  [0.36363636 0.28125    0.13207547 ... 0.00909894 0.27272727 1.        ]
#  [0.36363636 0.3125     0.16679245 ... 0.00418246 0.09090909 1.        ]
#  ...
#  [0.27272727 0.25       0.17584906 ... 0.00821673 0.90909091 0.        ]
#  [0.18181818 0.125      0.04603774 ... 0.0044122  0.27272727 1.        ]
#  [0.36363636 0.4375     0.24226415 ... 0.01018447 0.72727273 0.        ]]

# %% [markdown]
# ### Following you will predict the output based on the input data X_test.
#
# Lonk to API - https://keras.io/api/models/model_training_apis/#predict-method

# %% [markdown]
# _________________![image.png](attachment:022befb0-8c76-4286-b616-6e938a4af5b5.png)

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# #### Following code will test the error in the predicted values.
# #### Error is the difference between the predictions you made and real values (y_test)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
print (mean_absolute_error(y_test, predictions))
print (np.sqrt(mean_squared_error(y_test,predictions)))
print (explained_variance_score(y_test,predictions))
# Out:
# 115837.73913250405
# 186999.24669969344
# 0.7507187184021885

# %% [markdown]
# The following code plots the predicted values in a scatter plot. We have also plotted the perfect predictions.

# %% [markdown]
# ______![image.png](attachment:8e4d2cc0-974e-4100-9196-c3f50cbaa0c0.png)

# %%
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %% [markdown]
# In the following code, we have plotted the error i.e. the difference between the actual and predicted values.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run all next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
errors = y_test.values.reshape(6484, 1) - predictions
sns.distplot(errors)
# Out:
# /tmp/ipykernel_11828/822056149.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(errors)
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Following code makes prediction on a brand new house.
#
# !!! Comment each line of the code.
#
# Try predicting price for a new home.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run all next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %% [markdown]
# ______________________![image.png](attachment:d73fc573-12bc-4349-a05e-05b091b055c1.png)

# %%
df['price'].iloc[0]
# Out:
# np.float64(221900.0)

# %% [markdown]
# ______________________![image.png](attachment:c95f561e-1384-4963-9ec6-15fbb13b0976.png)

# %%
single_house = X.iloc[0]
single_house
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# month              10.0000
# year             2014.0000
# Name: 0, dtype: float64

# %%
single_house.size
# Out:
# 19

# %% [markdown]
# __________________![image.png](attachment:2276d544-9013-429e-b1d7-119447342d1a.png)

# %%
single_house = scaler.transform(single_house.values.reshape(1, 19))
single_house
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([[0.27272727, 0.125     , 0.06716981, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.5       , 0.09758772,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00573322, 0.81818182, 0.        ]])

# %% [markdown]
# __________________________![image.png](attachment:e67f6437-f78d-444a-ba79-b996aaaef48e.png)

# %%
model.predict(single_house)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# array([[265642.34]], dtype=float32)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run all next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# The prediction result:

err = int(model.predict(single_house)) - df['price'].iloc[0]

print( 'absolute prediction error = ', err, ' $')
print( 'relative prediction error = ', err / df['price'].iloc[0] *100 , ' %')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# absolute prediction error =  43742.0  $
# relative prediction error =  19.71248310049572  %
# /tmp/ipykernel_11828/3423301771.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   err = int(model.predict(single_house)) - df['price'].iloc[0]

# %% [markdown]
# <html> <h2 style="font-style:bold; color:red;"> Lab Logbook requirements </h2> </html>
#
# ### Please record the plot of the  model's  loss after every epoch and a summary in lab logbook. You can obtain the model summary using the model.summary() method. The API for obtaining the model summary is defined in the following link:
#
# ### https://keras.io/api/models/model/#summary-method
#
# ### Ensure that no code or other information is added to the logbook and that only required information is present.  Marks will not be awarded if anything else is found in the logbook or instructions are not clearly followed.

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1))

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 402636898304.0000 - val_loss: 250829996032.0000
# Epoch 2/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 140688179200.0000 - val_loss: 81039933440.0000
# Epoch 3/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 100531396608.0000 - val_loss: 77650780160.0000
# Epoch 4/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95722184704.0000 - val_loss: 73647456256.0000
# Epoch 5/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90475708416.0000 - val_loss: 69183201280.0000
# Epoch 6/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 84528594944.0000 - val_loss: 63978536960.0000
# Epoch 7/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 78116413440.0000 - val_loss: 59310530560.0000
# Epoch 8/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 71506894848.0000 - val_loss: 54069301248.0000
# Epoch 9/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 65396015104.0000 - val_loss: 49645023232.0000
# Epoch 10/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 60551884800.0000 - val_loss: 46763085824.0000
# Epoch 11/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 57139658752.0000 - val_loss: 44719894528.0000
# Epoch 12/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 54878359552.0000 - val_loss: 43325796352.0000
# Epoch 13/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 53267099648.0000 - val_loss: 42292834304.0000
# Epoch 14/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 52015251456.0000 - val_loss: 41606549504.0000
# Epoch 15/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 50895122432.0000 - val_loss: 40583704576.0000
# Epoch 16/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 49903771648.0000 - val_loss: 40294924288.0000
# Epoch 17/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 49053982720.0000 - val_loss: 39403335680.0000
# Epoch 18/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 48165945344.0000 - val_loss: 38789554176.0000
# Epoch 19/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 47456485376.0000 - val_loss: 38173949952.0000
# Epoch 20/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 46720126976.0000 - val_loss: 37640912896.0000
# Epoch 21/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 46070349824.0000 - val_loss: 37139312640.0000
# Epoch 22/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 45395935232.0000 - val_loss: 37099208704.0000
# Epoch 23/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 44703956992.0000 - val_loss: 36201242624.0000
# Epoch 24/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 44095467520.0000 - val_loss: 35788808192.0000
# Epoch 25/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 43563728896.0000 - val_loss: 35440287744.0000
# Epoch 26/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 42864533504.0000 - val_loss: 35067392000.0000
# Epoch 27/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42274357248.0000 - val_loss: 35156824064.0000
# Epoch 28/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41720320000.0000 - val_loss: 34407911424.0000
# Epoch 29/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 41117970432.0000 - val_loss: 34054746112.0000
# Epoch 30/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 40620036096.0000 - val_loss: 33968803840.0000
# Epoch 31/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 40171937792.0000 - val_loss: 33636718592.0000
# Epoch 32/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39603220480.0000 - val_loss: 33582594048.0000
# Epoch 33/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39264976896.0000 - val_loss: 33234075648.0000
# Epoch 34/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38812270592.0000 - val_loss: 33078677504.0000
# Epoch 35/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38449864704.0000 - val_loss: 32867031040.0000
# Epoch 36/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 38145875968.0000 - val_loss: 32791019520.0000
# Epoch 37/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37828227072.0000 - val_loss: 32679432192.0000
# Epoch 38/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37595193344.0000 - val_loss: 32498855936.0000
# Epoch 39/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37292556288.0000 - val_loss: 32612370432.0000
# Epoch 40/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36937621504.0000 - val_loss: 33027987456.0000
# Epoch 41/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 36863148032.0000 - val_loss: 32254613504.0000
# Epoch 42/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 36527038464.0000 - val_loss: 32117047296.0000
# Epoch 43/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36379398144.0000 - val_loss: 31929395200.0000
# Epoch 44/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 36175822848.0000 - val_loss: 31984011264.0000
# Epoch 45/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 36096856064.0000 - val_loss: 32099801088.0000
# Epoch 46/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35886551040.0000 - val_loss: 31898914816.0000
# Epoch 47/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35739512832.0000 - val_loss: 31881717760.0000
# Epoch 48/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35600621568.0000 - val_loss: 31633362944.0000
# Epoch 49/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35442913280.0000 - val_loss: 31716921344.0000
# Epoch 50/50
# 379/379 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 35328724992.0000 - val_loss: 31956742144.0000

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 128)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,789 (151.52 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 25,860 (101.02 KB)

# %% [markdown]
# # <html> <h3 style="font-style:bold; color:blue;"> Try different optimisations like changing model architecture, activation functions, training parameters. </h3> </html>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss Over Epochs')
plt.show()

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1))

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 167982612480.0000 - val_loss: 68491083776.0000
# Epoch 2/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 72591179776.0000 - val_loss: 46659538944.0000
# Epoch 3/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 53876002816.0000 - val_loss: 40786173952.0000
# Epoch 4/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 48390975488.0000 - val_loss: 37383356416.0000
# Epoch 5/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 44715388928.0000 - val_loss: 35864666112.0000
# Epoch 6/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 42210082816.0000 - val_loss: 34563489792.0000
# Epoch 7/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 40285646848.0000 - val_loss: 33815529472.0000
# Epoch 8/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 38939357184.0000 - val_loss: 36040208384.0000
# Epoch 9/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 37731393536.0000 - val_loss: 32994795520.0000
# Epoch 10/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 36862853120.0000 - val_loss: 32069584896.0000
# Epoch 11/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 36323368960.0000 - val_loss: 31932452864.0000
# Epoch 12/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 35545608192.0000 - val_loss: 31327928320.0000
# Epoch 13/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 35328577536.0000 - val_loss: 32234975232.0000
# Epoch 14/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34844000256.0000 - val_loss: 31081449472.0000
# Epoch 15/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34732990464.0000 - val_loss: 31586338816.0000
# Epoch 16/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34395725824.0000 - val_loss: 30764025856.0000
# Epoch 17/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34200893440.0000 - val_loss: 30718402560.0000
# Epoch 18/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33969414144.0000 - val_loss: 30311049216.0000
# Epoch 19/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 33747965952.0000 - val_loss: 30212212736.0000
# Epoch 20/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 33443086336.0000 - val_loss: 29850839040.0000
# Epoch 21/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 33154201600.0000 - val_loss: 31092766720.0000
# Epoch 22/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33297188864.0000 - val_loss: 30246295552.0000
# Epoch 23/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33096202240.0000 - val_loss: 29820602368.0000
# Epoch 24/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32900495360.0000 - val_loss: 29855127552.0000
# Epoch 25/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32695140352.0000 - val_loss: 29474717696.0000
# Epoch 26/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32570122240.0000 - val_loss: 28734087168.0000
# Epoch 27/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32409036800.0000 - val_loss: 28514295808.0000
# Epoch 28/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32463706112.0000 - val_loss: 28310202368.0000
# Epoch 29/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 32100960256.0000 - val_loss: 29915451392.0000
# Epoch 30/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32022773760.0000 - val_loss: 28465954816.0000
# Epoch 31/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32004413440.0000 - val_loss: 29233786880.0000
# Epoch 32/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31846934528.0000 - val_loss: 27768643584.0000
# Epoch 33/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31667007488.0000 - val_loss: 28065599488.0000
# Epoch 34/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 31548127232.0000 - val_loss: 28057073664.0000
# Epoch 35/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 31500990464.0000 - val_loss: 29179688960.0000
# Epoch 36/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 31388346368.0000 - val_loss: 27231899648.0000
# Epoch 37/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31324188672.0000 - val_loss: 27380297728.0000
# Epoch 38/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30991255552.0000 - val_loss: 27958345728.0000
# Epoch 39/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 30957023232.0000 - val_loss: 26872356864.0000
# Epoch 40/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 30661361664.0000 - val_loss: 26697779200.0000
# Epoch 41/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30707038208.0000 - val_loss: 26752798720.0000
# Epoch 42/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30606479360.0000 - val_loss: 26516373504.0000
# Epoch 43/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30392633344.0000 - val_loss: 26995288064.0000
# Epoch 44/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 30151653376.0000 - val_loss: 27576985600.0000
# Epoch 45/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 30022053888.0000 - val_loss: 26788274176.0000
# Epoch 46/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29939890176.0000 - val_loss: 26354255872.0000
# Epoch 47/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29661427712.0000 - val_loss: 26140182528.0000
# Epoch 48/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 29580869632.0000 - val_loss: 25918392320.0000
# Epoch 49/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29302802432.0000 - val_loss: 27185160192.0000
# Epoch 50/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29409318912.0000 - val_loss: 26898063360.0000
# Epoch 51/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29280970752.0000 - val_loss: 30110294016.0000
# Epoch 52/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29138610176.0000 - val_loss: 25659936768.0000
# Epoch 53/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28892555264.0000 - val_loss: 25666347008.0000
# Epoch 54/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28851275776.0000 - val_loss: 25589407744.0000
# Epoch 55/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28602208256.0000 - val_loss: 25261725696.0000
# Epoch 56/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28549916672.0000 - val_loss: 25414588416.0000
# Epoch 57/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28663007232.0000 - val_loss: 26333818880.0000
# Epoch 58/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28498405376.0000 - val_loss: 26419585024.0000
# Epoch 59/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28371689472.0000 - val_loss: 24953718784.0000
# Epoch 60/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28041222144.0000 - val_loss: 24928389120.0000
# Epoch 61/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28035209216.0000 - val_loss: 24775090176.0000
# Epoch 62/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27989319680.0000 - val_loss: 24715083776.0000
# Epoch 63/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27729985536.0000 - val_loss: 24846055424.0000
# Epoch 64/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27849801728.0000 - val_loss: 24653295616.0000
# Epoch 65/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27392206848.0000 - val_loss: 25433163776.0000
# Epoch 66/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27596900352.0000 - val_loss: 24474013696.0000
# Epoch 67/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27598110720.0000 - val_loss: 24593731584.0000
# Epoch 68/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27461586944.0000 - val_loss: 24168118272.0000
# Epoch 69/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27400906752.0000 - val_loss: 24118480896.0000
# Epoch 70/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27052843008.0000 - val_loss: 24115625984.0000
# Epoch 71/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27205113856.0000 - val_loss: 24278824960.0000
# Epoch 72/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26986369024.0000 - val_loss: 24378273792.0000
# Epoch 73/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27149017088.0000 - val_loss: 24278138880.0000
# Epoch 74/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 27124480000.0000 - val_loss: 24302102528.0000
# Epoch 75/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26876778496.0000 - val_loss: 23738787840.0000
# Epoch 76/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 26673672192.0000 - val_loss: 23987091456.0000
# Epoch 77/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26782855168.0000 - val_loss: 24326979584.0000
# Epoch 78/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26465325056.0000 - val_loss: 24647673856.0000
# Epoch 79/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26845083648.0000 - val_loss: 23555618816.0000
# Epoch 80/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26534295552.0000 - val_loss: 23530741760.0000
# Epoch 81/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26584897536.0000 - val_loss: 24025219072.0000
# Epoch 82/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 26367420416.0000 - val_loss: 24480890880.0000
# Epoch 83/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 26412838912.0000 - val_loss: 24541333504.0000
# Epoch 84/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25938501632.0000 - val_loss: 23968714752.0000
# Epoch 85/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25735487488.0000 - val_loss: 22732906496.0000
# Epoch 86/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25625585664.0000 - val_loss: 23017668608.0000
# Epoch 87/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 25393049600.0000 - val_loss: 22596841472.0000
# Epoch 88/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25098356736.0000 - val_loss: 22328084480.0000
# Epoch 89/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25071484928.0000 - val_loss: 21974016000.0000
# Epoch 90/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 24759853056.0000 - val_loss: 22343227392.0000
# Epoch 91/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 24428032000.0000 - val_loss: 22019622912.0000
# Epoch 92/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 24203677696.0000 - val_loss: 21351608320.0000
# Epoch 93/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 23977441280.0000 - val_loss: 20807127040.0000
# Epoch 94/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 23368630272.0000 - val_loss: 20896139264.0000
# Epoch 95/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 23255373824.0000 - val_loss: 20973881344.0000
# Epoch 96/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 23202748416.0000 - val_loss: 20159348736.0000
# Epoch 97/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 22891255808.0000 - val_loss: 19959001088.0000
# Epoch 98/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 22487738368.0000 - val_loss: 20479954944.0000
# Epoch 99/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 22454540288.0000 - val_loss: 19923312640.0000
# Epoch 100/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 21956816896.0000 - val_loss: 19346882560.0000

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_13 (Dense)                │ (None, 256)            │         5,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,157 (567.02 KB)
#  Trainable params: 48,385 (189.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 96,772 (378.02 KB)

# %%
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Optimised Model Loss Over Epochs')
plt.show()
